# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series(["a",1,'b','c','d'])
s
# Out:
# 0    a
# 1    1
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
frutas = ["pera",'manzana','naranja','banana']
cantidad = [23,45,89,10]
g =pd.Series(cantidad, index=frutas)
g
# Out:
# pera       23
# manzana    45
# naranja    89
# banana     10
# dtype: int64

# %%
g["pera"]
# Out:
# 23

# %%
g.describe()
# Out:
# count     4.000000
# mean     41.750000
# std      34.654245
# min      10.000000
# 25%      19.750000
# 50%      34.000000
# 75%      56.000000
# max      89.000000
# dtype: float64

# %%
link = "https://drive.google.com/file/d/10DlQOgSPz422rYV_MQHCHRQWqDFOMOXM/view?usp=sharing"
df = pd.read_csv(link, sep=',')

# %%
df
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="jIy-iadqCH8ObPY_7NIMVw">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>arrh
# ...

# %%
import io
import requests

# URL del archivo en Google Drive
url = link

# Obtener el ID del archivo de Google Drive
file_id = url.split('/')[-2]

# Generar la URL de descarga directa
download_url = f'https://drive.google.com/uc?id={file_id}'

# Hacer una solicitud GET a la URL de descarga directa
response = requests.get(download_url)

# Leer los datos directamente desde la respuesta de la solicitud
df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))

# Mostrar las primeras filas del DataFrame
df
# Out:
#      age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  \
# 0     75    0     190      80           91         193          371
# 1     56    1     165      64           81         174          401
# 2     54    0     172      95          138         163          386
# 3     55    0     175      94          100         202          380
# 4     75    0     190      80           88         181          360
# ..   ...  ...     ...     ...          ...         ...          ...
# 447   53    1     160      70           80         199          382
# 448   37    0     190      85          100         137          361
# 449   36    0     166      68          108         176          365
# 450   32    1     155      55           93         106          386
# 451   78    1     160      70           79         127          364
#
#      Tinterval  Pinterval  QRS  ...  chV6_QwaveAmp  chV6_RwaveAmp  \
# 0          174        121  -16  ...            0.0            9.0
# ...

# %%
df2 = df.loc[5]
df2
# Out:
# age               13.0
# sex                0.0
# height           169.0
# weight            51.0
# QRSduration      100.0
#                  ...
# chV6_PwaveAmp      0.9
# chV6_TwaveAmp      2.2
# chV6_QRSA         13.5
# chV6_QRSTA        31.1
# class             14.0
# Name: 5, Length: 280, dtype: float64
